# %%
# !pip install langchain
# Install latest versions
# !pip install -U langchain langchain-core langchain-community

from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
# Out:
# Requirement already satisfied: langchain in c:\users\asus\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\asus\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\asus\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.2.3)
# Requirement already satisfied: langchain in c:\users\asus\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core in c:\users\asus\anaconda3\lib\site-packages (1.2.28)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\asus\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\asus\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\asus\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\asus\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asus\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\asus\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 3.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 5.6 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.4 MB/s eta 0:00:00
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Installing collected packages: typing-inspect, requests, marshmallow, httpx-sse, dataclasses-json, pydantic-settings, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.3 langchain-classic-1.0.3 langchain-community-0.4.1 langchain-text-splitters-1.1.1 marshmallow-3.26.2 pydantic-settings-2.13.1 requests-2.33.1 typing-inspect-0.9.0
# Explain AI in simple terms for beginners
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story
# [SystemMessage(content='You are a helpful teacher', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]
# Explain Neural Networks as a story for beginner in a fun tone
# Explain AI in simple terms
# Explain Python in simple terms
# Explain Data Science in simple terms
# Explain NLP in simple terms
# Explain Deep Learning in simple terms

# %% [markdown]
# # Task 1: Replace Hardcoded Prompt

# %%
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)
print(template_1.format(topic="AI"))
# Out:
# Explain AI in simple terms for beginners

# %% [markdown]
# # Task 2: Multi-Input Prompt System

# %%
multi_input_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

print(multi_input_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_input_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_input_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# # Task 3: Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# # Task 4: ChatPromptTemplate System

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful {role}"),
    ("user", "Explain {topic}")
])

messages = chat_template.format_messages(role="teacher", topic="Neural Networks")
print(messages)
# Out:
# [SystemMessage(content='You are a helpful teacher', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # Task 5: Input Validation

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]

    if audience not in valid_audience:
        print("Invalid audience, setting default: beginner")
        audience = "beginner"

    if tone not in valid_tone:
        print("Invalid tone, setting default: formal")
        tone = "formal"

    return audience, tone

# Call function
audience, tone = validate_inputs("kids", "friendly")

print(audience, tone)
# Out:
# Invalid audience, setting default: beginner
# Invalid tone, setting default: formal
# beginner formal

# %% [markdown]
# # Task 6: Prompt Generator App

# %%
def generate_prompt(topic, audience, tone, style):
    audience, tone = validate_inputs(audience, tone)

    styles = {
        "teaching": "Explain {topic} for {audience} in a {tone} teaching style",
        "interview": "Ask interview questions about {topic} for {audience} in a {tone} tone",
        "storytelling": "Explain {topic} as a story for {audience} in a {tone} tone"
    }

    template = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=styles[style]
    )

    return template.format(topic=topic, audience=audience, tone=tone)


print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))

# %% [markdown]
# # Task 7: Reusability Test

# %%
reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = ["AI", "Python", "Data Science", "NLP", "Deep Learning"]

for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Explain AI in simple terms
# Explain Python in simple terms
# Explain Data Science in simple terms
# Explain NLP in simple terms
# Explain Deep Learning in simple terms
